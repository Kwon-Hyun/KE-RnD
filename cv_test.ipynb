# %% [markdown]
# ### Library

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The kernel failed to start as the Python Environment 'robot_test (Python)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
