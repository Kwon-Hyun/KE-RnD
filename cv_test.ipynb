# %% [markdown]
# ### Library

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
print("opencv version : ", cv.__version__)
print("Installation Finish !")
# Out:
# opencv version :  4.12.0
# Installation Finish !

# %%
# 이미지 읽기
image = cv.imread('img\20hole_h_II.jpg')

# %%
# 이미지 표시
cv.imshow('img\20hole_h_II.jpg', image)
cv.waitKey(0)
cv.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 이미지 표시
# ----> 2 cv.imshow('img\20hole_h_II.jpg', image)
#       3 cv.waitKey(0)
#       4 cv.destroyAllWindows
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
